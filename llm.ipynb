# %%
# %pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (0.23.3)
# Requirement already satisfied: filelock in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (3.12.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (2023.9.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (4.10.0)
# Requirement already satisfied: colorama in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yoga duet\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_huggingface import HuggingFaceEndpoint

ACCESS_TOKEN = "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"

llm = HuggingFaceEndpoint(
    repo_id="HuggingFaceH4/zephyr-7b-beta",
    task="text-generation",
    huggingfacehub_api_token=ACCESS_TOKEN,
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to C:\Users\Yoga Duet\.cache\huggingface\token
# Login successful

# %%
from langchain_huggingface import ChatHuggingFace

chat_model = ChatHuggingFace(llm=llm)
print(chat_model.invoke("Hello").content)
# Out:
# Hello, I'm happy to assist you. Please let me know how I can be of service today. If you're looking for information about a specific topic, just ask, and I'll do my best to provide the correct answer. Alternatively, feel free to share your thoughts or ideas with me, and I'll offer my perspective. Whatever you need, I'm here to help!
